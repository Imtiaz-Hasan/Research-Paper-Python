# %% [markdown]
# <a href="https://colab.research.google.com/github/Imtiaz-Hasan/All-Project/blob/master/Covid-19_vaccine_side_effect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/dataset1/main2.xlsx")
df.head()
# Out:
#    TOS         VAX_MANU  AGE_YRS SEX
# 0    2          MODERNA     33.0   F
# 1    2          MODERNA     73.0   F
# 2    4  PFIZER\BIONTECH     23.0   F
# 3    3          MODERNA     58.0   F
# 4    4          MODERNA     47.0   F

# %%
df.to_excel("piechartdata1.xlsx")

# %% [markdown]
# # **Symptoms affected on female**

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["TOS","AGE_YRS"]]
fdata
# Out:
#         TOS  AGE_YRS
# 2         4     23.0
# 17        3     29.0
# 20        2     24.0
# 24        4     25.0
# 25        5     22.0
# ...     ...      ...
# 811885    1     22.0
# 811919    5     28.0
# 811920    1     28.0
# 811960    5     29.0
# 811991    1     29.0
#
# [59615 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

from collections import Counter

# %%
print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 21870, 1: 10939, 2: 10145, 3: 9078, 4: 7583})
# Counter({1: 10939, 2: 10145, 3: 9078, 4: 7583, 5: 21870})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

# %%
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 21-30)')
plt.show()

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 36888, 1: 16359, 2: 15727, 3: 13827, 4: 12116})
# Counter({1: 16359, 2: 15727, 3: 13827, 4: 12116, 5: 36888})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 31-40)')
plt.show()

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 38982, 1: 16651, 2: 15317, 3: 14368, 4: 12358})
# Counter({1: 16651, 2: 15317, 3: 14368, 4: 12358, 5: 38982})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 41-50)')
plt.show()

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 37652, 1: 16915, 2: 15686, 3: 14077, 4: 12028})
# Counter({1: 16915, 2: 15686, 3: 14077, 4: 12028, 5: 37652})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 51-60)')
plt.show()

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 33119, 1: 15755, 2: 14495, 3: 12974, 4: 11087})
# Counter({1: 15755, 2: 14495, 3: 12974, 4: 11087, 5: 33119})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 61-70)')
plt.show()

# %%
fdata=df[(df.SEX=="F") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 17682, 1: 9713, 2: 8622, 3: 7848, 4: 6352})
# Counter({1: 9713, 2: 8622, 3: 7848, 4: 6352, 5: 17682})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Female (Age 71-80)')
plt.show()

# %% [markdown]
# # **Symptoms affected on Male**

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=21) &(df['AGE_YRS']<=30)][["TOS","AGE_YRS"]]
fdata
# Out:
#         TOS  AGE_YRS
# 21        2     28.0
# 39        5     27.0
# 147       2     23.0
# 163       3     30.0
# 169       3     27.0
# ...     ...      ...
# 811381    5     28.0
# 811382    3     28.0
# 811388    5     23.0
# 811644    1     23.0
# 811874    5     22.0
#
# [24278 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 7821, 1: 5439, 2: 4536, 3: 3550, 4: 2932})
# Counter({1: 5439, 2: 4536, 3: 3550, 4: 2932, 5: 7821})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 21-30)')
plt.show()

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=31) &(df['AGE_YRS']<=40)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 10239, 1: 6646, 2: 5505, 3: 4293, 4: 3621})
# Counter({1: 6646, 2: 5505, 3: 4293, 4: 3621, 5: 10239})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 31-40)')
plt.show()

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=41) &(df['AGE_YRS']<=50)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 9787, 1: 6740, 2: 5447, 3: 4197, 4: 3415})
# Counter({1: 6740, 2: 5447, 3: 4197, 4: 3415, 5: 9787})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 41-50)')
plt.show()

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=51) &(df['AGE_YRS']<=60)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 11275, 1: 7916, 2: 6232, 3: 4856, 4: 3785})
# Counter({1: 7916, 2: 6232, 3: 4856, 4: 3785, 5: 11275})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 51-60)')
plt.show()

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=61) &(df['AGE_YRS']<=70)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 12001, 1: 8297, 2: 6776, 3: 4985, 4: 4065})
# Counter({1: 8297, 2: 6776, 3: 4985, 4: 4065, 5: 12001})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 61-70)')
plt.show()

# %%
fdata=df[(df.SEX=="M") &(df['AGE_YRS']>=71) &(df['AGE_YRS']<=80)][["TOS","AGE_YRS"]]
fdata

import matplotlib.pyplot as plt

from collections import Counter

print(Counter(fdata['TOS']))
dict=Counter(fdata['TOS'])
dict
# Out:
# Counter({5: 8663, 1: 5865, 2: 5014, 3: 3504, 4: 2759})
# Counter({1: 5865, 2: 5014, 3: 3504, 4: 2759, 5: 8663})

# %%
labels=[]
for x, y in dict.items():
  labels.append(str(x)+" types of symptoms")
sizes=[]
for x, y in dict.items():
  sizes.append(y)

plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Symptoms affected on Male (Age 71-80)')
plt.show()

# %%
import pandas as pd
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

df = pd.read_excel("/content/drive/MyDrive/dataset1/main2.xlsx")

sums = df.groupby(df["VAX_MANU"])["TOS"].sum()
axis('equal');
pie(sums, labels=sums.index, autopct='%1.1f%%');

show()

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

x = ['Moderna Female', 'Moderna Male', 'Pfizer Female', 'Pfizer Male', 'Janssen Female', 'Janssen Male']
y = [273924, 97337, 242089, 103691, 47395, 25533]

width = 0.35
fig, ax = plt.subplots()

pps = ax.bar(x, y, width, align='center')

for p in pps:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}".format(height),
      ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt



labels = ['1 type of symptom', '2 types of symptom', '3 types of symptom','4 types of symptom','5 types of symptom']

sections = [77141, 64242, 50455,39357,120963]

colors = ['C', 'g', 'm','r','y']



plt.pie(sections, labels=labels, colors=colors,

        startangle=90,

        explode = (0, 0, 0,0,0),

        autopct = '%1.2f%%')



plt.axis('equal') 

plt.title('Symptoms affected by using Pfizer')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.

# %%
import matplotlib.pyplot as plt



labels = ['1 type of symptom', '2 types of symptom', '3 types of symptom','4 types of symptom','5 types of symptom']

sections = [14486, 13056, 10638,8946,30050]

colors = ['C', 'g', 'm','r','y']



plt.pie(sections, labels=labels, colors=colors,

        startangle=90,

        explode = (0, 0, 0,0,0),

        autopct = '%1.2f%%')



plt.axis('equal') 

plt.title('Symptoms affected by using Janssen')

plt.show()

# %%
import matplotlib.pyplot as plt



labels = ['1 type of symptom', '2 types of symptom', '3 types of symptom','4 types of symptom','5 types of symptom']

sections = [81987, 65728, 57054,47340,130544]

colors = ['C', 'g', 'm','r','y']



plt.pie(sections, labels=labels, colors=colors,

        startangle=90,

        explode = (0, 0, 0,0,0),

        autopct = '%1.2f%%')



plt.axis('equal') 

plt.title('Symptoms affected by using Moderna')

plt.show()
